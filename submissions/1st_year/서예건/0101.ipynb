# %% [markdown]
# # 파이썬 기초: 내 마음대로 데이터 저장하기
# ## 1단계: 변수(Variable)가 뭔가요?
#
# 컴퓨터에게 어떤 값을 기억시키고 싶을 때, 우리는 **'이름표가 붙은 그릇'** 을 사용합니다.
# 이 그릇을 **'변수'** 라고 불러요.
#
# ### 📥 값을 넣는 법 (대입)
# `a = 10` 이라는 코드는 수학의 "a와 10이 같다"는 뜻이 아니에요!
# **"10이라는 데이터를 `a`라는 변수에 집어넣어라!"** 라는 명령입니다.
#
# * **왼쪽(`a`)**: 그릇의 이름 (내 맘대로 지을 수 있음! 단, 숫자로 시작하거나 일부 정해진 단어는 안 됨)
# * **오른쪽(`10`)**: 그릇에 담을 내용물
# * **가운데(`=`)**: "집어넣어!" 라는 화살표 역할

# %%
# 1. 'apple'이라는 그릇에 숫자 5를 담아봅시다.
apple = 5

# 2. 'banana'라는 그릇에 숫자 10을 담아봅시다.
banana = 10

# 3. 이제 그릇의 이름을 부르면 내용물이 나옵니다!
# 참고로 print()는 괄호 안의 내용물을 출력하라는 뜻이에요.
print(apple)
print(banana)
print(apple + banana) # 그릇 안의 내용물끼리 더할 수도 있어요.

# %% [markdown]
# ---
# ### 📝 [실습 0] 나만의 변수 만들기
# 1. `my_lucky_number`라는 이름의 그릇을 만들고, 좋아하는 숫자를 넣어보세요.
# 2. `print(my_lucky_number)`를 해서 숫자가 잘 나오는지 확인해보세요!

# %%
# 여기에 코드를 작성해보세요

# %% [markdown]
# ### 1. 자료형(Data Type): 데이터의 세 가지 얼굴 🎭
# 가장 자주 쓰는 세 가지를 꼭 기억하세요!
#
# 1. **정수 (int)**: 딱 떨어지는 숫자 (예: 1, 100, -5)
# 2. **실수 (float)**: 소수점이 있는 숫자 (예: 3.14, 0.5)
# 3. **문자열 (str)**: 글자 덩어리. 반드시 **큰따옴표(" ")** 나 **작은따옴표(' ')** 로 감싸야 해요! (예: "베리타스", 'Python')

# %%
# 자료형 확인하기: type() 이라는 마법 도구를 써봅시다.

a = 10
b = 3.14
c = "파이썬"

print(type(a))
print(type(b))
print(type(c))

# "10"은 숫자일까요, 문자일까요?
print(type("10"))

# %% [markdown]
# ---
# ## 2. 파이썬의 계산기 기능 (연산자)
# 파이썬은 아주 강력한 계산기입니다. 숫자형 데이터(int, float)를 가지고 다양한 산술 연산을 할 수 있어요.
#
# ### ➕ 산술 연산자
# * `+`, `-`, `*`, `/` : 더하기, 빼기, 곱하기, 나누기
# * `//` : **몫** (나눗셈 후 소수점 버림)
# * `%` : **나머지** (홀짝 판별이나 배수 찾기에 필수!)
# * `**` : **거듭제곱** (예: 2의 10제곱)
#
# ### ⚖️ 비교 연산자 (결과는 항상 True 아니면 False!)
# * `==` : 같다 (수학의 =와 다름에 주의!)
# * `!=` : 다르다
# * `>`, `<`, `>=`, `<=` : 크기 비교

# %%
# [실습] 직접 실행해서 결과를 예측해보세요.
a = 10
b = 3

print(f"10 나누기 3의 몫: {a // b}")
print(f"10 나누기 3의 나머지: {a % b}")
print(f"2의 10제곱: {2 ** 10}")

# 비교 연산 결과 확인
print(f"a와 b는 같은가? {a == b}")
print(f"a는 5보다 큰가? {a > 5}")

# %% [markdown]
# ---
# ### 📝 [실습 1] 연산자 활용 미션
# 어떤 숫자 `n`이 주어졌을 때, 이 숫자가 **'5의 배수'** 인지 확인하는 조건식을 만들어보고 싶습니다.
# 아래 코드의 빈칸을 채워보세요.
# (힌트: 5로 나눈 나머지가 0이면 5의 배수겠죠?)

# %%
n = int(input("숫자를 입력하세요: "))

# 여기에 n이 5의 배수인지 확인하는 print문을 작성해보세요.
# input()은 문자열을 입력받는 함수예요.
# 예를 들어
# a = input()
# 위 코드를 작성한 후 실행하면 변수 a의 값은 입력받은 문자열이 되는 거죠!
# input 함수의 괄호 안의 문자열은 입력받을 때 출력되는 문자예요.

# %%
미친샊
