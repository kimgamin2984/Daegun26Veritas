# %% [markdown]
# # 02. 파이썬 제어문 및 함수 기초
# 이번 차시에서는 똑같은 작업을 반복하는 **반복문**과, 코드를 재사용 가능한 단위로 묶는 **함수**를 배워요.
# 설명은 주석을 참고하고, 각 셀의 [실습] 문제를 해결해 보세요.

# %%
# [1] 반복문 (for): 지정된 횟수나 범위만큼 코드를 반복 실행함.
# range(시작, 끝) -> 시작부터 '끝-1'까지 숫자를 생성함.

print("--- 1부터 5까지 반복 ---")
for i in range(1, 6):
    print(i,"번째 실행 중...")

# 리스트 안의 요소들을 하나씩 꺼내올 수도 있음.
clubs = ["Veritas", "AI", "Python"]
for club in clubs:
    print("우리 동아리 이름:",club)
# Out:
# --- 1부터 5까지 반복 ---
# 1 번째 실행 중...
# 2 번째 실행 중...
# 3 번째 실행 중...
# 4 번째 실행 중...
# 5 번째 실행 중...
# 우리 동아리 이름: Veritas
# 우리 동아리 이름: AI
# 우리 동아리 이름: Python

# %% [markdown]
# ---
# ### 📝 [실습 2] 1부터 20까지의 숫자 중 '3의 배수'만 출력하는 코드를 짜보세요.

# %%
#hint: 앞서 배운 연산자 중 하나를 활용해요
for i in range(5):
    print("Hello!")
# Out:
# Hello!
# Hello!
# Hello!
# Hello!
# Hello!

# %%
for i in "ABCD":
    print(i)
# Out:
# A
# B
# C
# D

# %%
for i in ["야구", "축구", "농구", "탁구", "배구"]:
    print("내가 제일 좋아하는 스포츠는",i+"야.")
# Out:
# 내가 제일 좋아하는 스포츠는 야구야.
# 내가 제일 좋아하는 스포츠는 축구야.
# 내가 제일 좋아하는 스포츠는 농구야.
# 내가 제일 좋아하는 스포츠는 탁구야.
# 내가 제일 좋아하는 스포츠는 배구야.

# %%
if 1<=8:
    print("진실")
# Out:
# 진실

# %%
i=5
if i>=9:
    print("true")
else:
    print("false")
# Out:
# false

# %%
n =int(input())
if n>=50:
    print(str(n)+"은(는) 50과 같거나 크다.")
else:
    print(str(n)+"은(는) 50보다 작다")
# Out:
# 51은(는) 50과 같거나 크다.
